# %% [markdown]
# # Medicare Fraud Detection

# %% [markdown]
# ### Data 698: Data Science Research Project - Spring 2019

# %% [markdown]
# ### Student: Chunhui Zhu

# %% [markdown]
# Medicare_Provider_Utilization_and_Payment_Data__Physician_and_Other_Supplier_PUF_CY2016.csv: https://data.cms.gov/Medicare-Physician-Supplier/Medicare-Provider-Utilization-and-Payment-Data-Phy/utc4-f9xp

# %% [markdown]
# LEIE2019.csv: https://oig.hhs.gov/exclusions/exclusions_list.asp

# %% [markdown]
# # PART I : Data Mining

# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib as plt

# %% [markdown]
# ### Step 1: LEIE-Fraud Data - Label Data

# %%
leie=pd.read_csv('LEIE2019.csv',low_memory=False)
leie.columns.values
# Out:
# array(['LASTNAME', 'FIRSTNAME', 'MIDNAME', 'BUSNAME', 'GENERAL',
#        'SPECIALTY', 'UPIN', 'NPI', 'DOB', 'ADDRESS', 'CITY', 'STATE',
#        'ZIP', 'EXCLTYPE', 'EXCLDATE', 'REINDATE', 'WAIVERDATE',
#        'WVRSTATE'], dtype=object)

# %%
#NPI is a very important unique id to identify a provider.
npi_leie= leie[leie.NPI!= 0]

# %%
fraud_list=npi_leie.NPI.values.tolist()

# %%
len(fraud_list)
# Out:
# 5036

# %% [markdown]
# ### Step 2: Detect fraud data between 2012-2016 using LEIE-Fraude Data

# %% [markdown]
# ### 2016

# %%
def find_fraud(checklist, fraud_list):
    fraud=[]   
    for x in checklist:
        if x in fraud_list:
            fraud.append(x)
    return (fraud)

# %%
data2016=pd.read_table('Medicare_Provider_Util_Payment_PUF_CY2016.txt',low_memory=False)

# %%
data2016.shape
# Out:
# (9714897, 26)

# %%
data2016.columns.values
# Out:
# array(['NPI', 'NPPES_PROVIDER_LAST_ORG_NAME', 'NPPES_PROVIDER_FIRST_NAME',
#        'NPPES_PROVIDER_MI', 'NPPES_CREDENTIALS', 'NPPES_PROVIDER_GENDER',
#        'NPPES_ENTITY_CODE', 'NPPES_PROVIDER_STREET1',
#        'NPPES_PROVIDER_STREET2', 'NPPES_PROVIDER_CITY',
#        'NPPES_PROVIDER_ZIP', 'NPPES_PROVIDER_STATE',
#        'NPPES_PROVIDER_COUNTRY', 'PROVIDER_TYPE',
#        'MEDICARE_PARTICIPATION_INDICATOR', 'PLACE_OF_SERVICE',
#        'HCPCS_CODE', 'HCPCS_DESCRIPTION', 'HCPCS_DRUG_INDICATOR',
#        'LINE_SRVC_CNT', 'BENE_UNIQUE_CNT', 'BENE_DAY_SRVC_CNT',
#        'AVERAGE_MEDICARE_ALLOWED_AMT', 'AVERAGE_SUBMITTED_CHRG_AMT',
#        'AVERAGE_MEDICARE_PAYMENT_AMT', 'AVERAGE_MEDICARE_STANDARD_AMT'],
#       dtype=object)

# %%
checklist2016=data2016['NPI'].unique()
len(checklist2016)
# Out:
# 1000925

# %%
fraud_2016=find_fraud(checklist2016,fraud_list)
print(fraud_2016)
# Out:
# [1003811167, 1003817743, 1003822834, 1003859885, 1003892746, 1003904830, 1013009729, 1013087741, 1013095975, 1013999002, 1023004587, 1023006129, 1033126651, 1043215650, 1043590250, 1053360966, 1053486704, 1063436517, 1063452167, 1063486090, 1063501823, 1063575561, 1063611499, 1063696508, 1063851285, 1073511192, 1083614770, 1083654826, 1083667562, 1083681423, 1093726556, 1093755134, 1104898634, 1104913789, 1104924349, 1114951407, 1124000427, 1124057245, 1124088380, 1124296298, 1124356043, 1134213796, 1134228794, 1134280779, 1134285059, 1134401136, 1134575681, 1144228834, 1144503418, 1154413110, 1154471621, 1164414769, 1164436960, 1164458006, 1164515003, 1164598140, 1174545271, 1174571285, 1184710691, 1184727745, 1184785354, 1194702076, 1194745695, 1194801662, 1205806163, 1205824117, 1205840451, 1205954955, 1205963402, 1215053665, 1215328323, 1215941349, 1215963715, 1215999578, 1225067044, 1225111933, 1225144264, 1235200775, 1235211095, 1245210764, 1245231406, 1245246925, 1245337864, 1245425974, 1255308797, 1255312625, 1255339677, 1255397204, 1255452454, 1275502932, 1275587123, 1275649048, 1275721144, 1285630186, 1285651638, 1285663682, 1285673012, 1285757310, 1295705291, 1295722163, 1295731479, 1295836245, 1306240171, 1306249826, 1306867742, 1306895578, 1306906854, 1316008766, 1316067051, 1316906456, 1316935406, 1316984750, 1316993520, 1326187626, 1326218959, 1336186600, 1336187814, 1346207776, 1346224821, 1346237096, 1356333645, 1356354252, 1366428773, 1376548552, 1376550442, 1376596726, 1386631869, 1386670461, 1396070603, 1396744892, 1407929698, 1417008756, 1417060120, 1427034271, 1427163427, 1437110319, 1437217601, 1437339900, 1447243373, 1447292297, 1447337936, 1457356768, 1457696908, 1467435487, 1467447557, 1467474882, 1467519124, 1467526855, 1477507739, 1487605515, 1487629796, 1497712418, 1497732994, 1497745905, 1497749089, 1497778153, 1497797526, 1497864151, 1508827395, 1508863531, 1518387760, 1528082740, 1528088325, 1528093184, 1528390259, 1538237482, 1538265947, 1538321047, 1538359104, 1548250129, 1548376965, 1548401292, 1548427164, 1558342378, 1558347468, 1558448951, 1558479147, 1568400596, 1568655975, 1578524237, 1578679221, 1578754362, 1588694343, 1588775118, 1598097529, 1598701633, 1598714784, 1598718520, 1598743262, 1598968059, 1619162898, 1619930260, 1629085105, 1629217872, 1639175763, 1639196108, 1639202351, 1639268782, 1639275969, 1659434108, 1659682482, 1669409298, 1669513701, 1669663100, 1679565204, 1679749188, 1689605818, 1689617482, 1689645608, 1699717843, 1720060460, 1720101900, 1730231259, 1730257775, 1730264854, 1740280957, 1740372358, 1740380997, 1750435103, 1750472825, 1760576755, 1770505729, 1770542151, 1780708594, 1790764207, 1790785277, 1801846597, 1801852488, 1821037094, 1831145929, 1831149087, 1831202126, 1831284470, 1831339902, 1831440122, 1841322104, 1841493707, 1841505153, 1851374664, 1851473334, 1861493009, 1861599813, 1871571406, 1871586933, 1871597310, 1881610673, 1881615268, 1881693109, 1881703726, 1881782373, 1891703997, 1891803318, 1902815087, 1902868409, 1902874456, 1902895543, 1902916984, 1902964331, 1912110636, 1912932815, 1912939760, 1922005321, 1922058767, 1932108701, 1932147410, 1932260064, 1942265061, 1942373923, 1952357303, 1952395881, 1952477622, 1962421198, 1962443739, 1962511915, 1972554228, 1972592947, 1972607398, 1982609723, 1982661385, 1982779799, 1982781506]

# %%
len(fraud_2016)
# Out:
# 281

# %%
fraud_df16=pd.DataFrame(fraud_2016)

# %%
fraud_df16.columns=['Fraud_id_16']

# %%
import pickle
fraud_df16_pkl=open("fraud_df16_pickle","wb")
pickle.dump(fraud_df16,fraud_df16_pkl)
fraud_df16_pkl.close()

# %%
fraud_df16_pkl=open("fraud_df16_pickle","rb")
fraud_df16=pickle.load(fraud_df16_pkl)
print(fraud_df16.head(5))
# Out:
#    Fraud_id_16
# 0   1003811167
# 1   1003817743
# 2   1003822834
# 3   1003859885
# 4   1003892746

# %%
fraud_df16.to_csv('fraud_df16.csv')

# %% [markdown]
# ### 2015

# %%
data2015=pd.read_table('Medicare_Provider_Util_Payment_PUF_CY2015.txt',low_memory=False)

# %%
data2015.shape
# Out:
# (9497892, 26)

# %%
checklist2015=data2015['npi'].unique()
len(checklist2015)
# Out:
# 968418

# %%
fraud_2015=find_fraud(checklist2015,fraud_list)
print(fraud_2015)
# Out:
# [1003042441, 1003811167, 1003817743, 1003822834, 1003859885, 1003885344, 1003892746, 1003904830, 1003972670, 1013009729, 1013087741, 1013095975, 1013097708, 1013999002, 1023004587, 1023006129, 1023079274, 1023119898, 1023166410, 1033126651, 1033145487, 1043215650, 1043219405, 1043238421, 1043257744, 1053360966, 1053372201, 1053450346, 1053486704, 1063436517, 1063452167, 1063477503, 1063486090, 1063501823, 1063526580, 1063537215, 1063575561, 1063611499, 1063696508, 1063851285, 1073511192, 1073524823, 1083614770, 1083654826, 1083667562, 1083681423, 1093726556, 1093755134, 1093814717, 1093851164, 1104809706, 1104898634, 1104913789, 1104924349, 1114106689, 1114922606, 1114951407, 1124000427, 1124016480, 1124057245, 1124088380, 1124089016, 1124192042, 1124296298, 1124356043, 1124423983, 1134213796, 1134228794, 1134280779, 1134285059, 1134286958, 1144214578, 1144228834, 1144503418, 1144511700, 1154337129, 1154349330, 1154413110, 1154471621, 1164414769, 1164436960, 1164458006, 1164459350, 1164515003, 1164598140, 1174510549, 1174545271, 1174561708, 1174571285, 1174576912, 1184644122, 1184659849, 1184710691, 1184727745, 1184785354, 1184937799, 1194702076, 1194745695, 1194801662, 1194893198, 1205023512, 1205806163, 1205824117, 1205840451, 1205874484, 1205954955, 1205963402, 1215053665, 1215081773, 1215099585, 1215328323, 1215917042, 1215941349, 1215951488, 1215963715, 1215999578, 1225022627, 1225029275, 1225067044, 1225111933, 1225144264, 1235135138, 1235138413, 1235186636, 1235200775, 1235211095, 1245210764, 1245231406, 1245246925, 1245264415, 1245279645, 1245298371, 1245337864, 1245425974, 1255309175, 1255312625, 1255339677, 1255397204, 1255452454, 1265531388, 1265784680, 1275502932, 1275587123, 1275649048, 1275721144, 1275748675, 1275773046, 1285613778, 1285630186, 1285651638, 1285663682, 1285673012, 1285676734, 1285757310, 1285784066, 1295705291, 1295722163, 1295731479, 1295836245, 1306240171, 1306249826, 1306867742, 1306894118, 1306895578, 1306906854, 1316008766, 1316067051, 1316906456, 1316935406, 1316947807, 1316984750, 1316993520, 1326151507, 1326187626, 1336107184, 1336132786, 1336186600, 1336187814, 1336248723, 1346207776, 1346224821, 1346237096, 1346239084, 1356333645, 1356354252, 1356450274, 1366428773, 1366474512, 1366509903, 1366514432, 1366533390, 1376548552, 1376550442, 1376596726, 1376698936, 1376737809, 1386631869, 1386649507, 1386670461, 1386695591, 1396070603, 1396744892, 1407062094, 1407867666, 1407929698, 1417008756, 1417060120, 1417938663, 1417967647, 1427000819, 1427034271, 1427090562, 1427163427, 1437110319, 1437217601, 1437339900, 1447243373, 1447280243, 1447292297, 1447337936, 1457356768, 1457485906, 1457696908, 1467400028, 1467435487, 1467447557, 1467474882, 1467526855, 1477507739, 1477524270, 1477571818, 1477596690, 1487605515, 1487629796, 1497712418, 1497722391, 1497732994, 1497743090, 1497745905, 1497749089, 1497778153, 1497797526, 1497864151, 1497878656, 1508827395, 1508863531, 1518387760, 1518908193, 1518927615, 1528082740, 1528087970, 1528088325, 1528093184, 1528152840, 1528171774, 1528390259, 1538200308, 1538237482, 1538265947, 1538321047, 1538359104, 1538395876, 1548250129, 1548376965, 1548401292, 1548427164, 1558342378, 1558347468, 1558366815, 1558379172, 1558405647, 1558448951, 1558478529, 1558479147, 1568400596, 1578524237, 1578679221, 1578697421, 1578754362, 1588694343, 1588775118, 1588798284, 1598097529, 1598701633, 1598713430, 1598714784, 1598718520, 1598743262, 1598781494, 1598968059, 1609808005, 1609829985, 1619085685, 1619117538, 1619162898, 1619168036, 1619930260, 1619941614, 1629085105, 1629150495, 1629153507, 1629217872, 1639124639, 1639169972, 1639175763, 1639196108, 1639202351, 1639268782, 1639275969, 1639363161, 1639395395, 1649317298, 1649331646, 1649401548, 1659320281, 1659434108, 1659495216, 1659703734, 1669409298, 1669412243, 1669454146, 1669513701, 1669640777, 1669663100, 1679565204, 1679606560, 1679749188, 1689605818, 1689617482, 1689645608, 1689742397, 1699717843, 1699748228, 170 ...

# %%
len(fraud_2015)
# Out:
# 475

# %%
fraud_df15=pd.DataFrame(fraud_2015)

# %%
fraud_df15.columns=['Fraud_id_15']

# %%
fraud_df15_pkl=open("fraud_df15_pickle","wb")
pickle.dump(fraud_df15,fraud_df15_pkl)
fraud_df15_pkl.close()

# %%
fraud_df15_pkl=open("fraud_df15_pickle","rb")
fraud_df15=pickle.load(fraud_df15_pkl)
print(fraud_df15.head(5))
# Out:
#    Fraud_id_15
# 0   1003042441
# 1   1003811167
# 2   1003817743
# 3   1003822834
# 4   1003859885

# %%
fraud_df15.to_csv('fraud_df15.csv')

# %% [markdown]
# ### 2014

# %%
data2014=pd.read_table('Medicare_Physician_and_Other_Supplier_NPI_Aggregate_CY2014.txt',low_memory=False)

# %%
data2014.shape
# Out:
# (986677, 70)

# %%
checklist2014=data2014['npi'].unique()
len(checklist2014)
# Out:
# 986677

# %%
fraud_2014=find_fraud(checklist2014,fraud_list)
print(fraud_2014)
# Out:
# [1003811167, 1003817743, 1003822834, 1003859885, 1003878711, 1003885344, 1003892746, 1003904830, 1003972670, 1013009729, 1013021047, 1013056670, 1013087741, 1013095975, 1013097708, 1013957182, 1013999002, 1023004587, 1023006129, 1023079274, 1023119898, 1023166410, 1033126651, 1033145487, 1033261953, 1033295332, 1043213887, 1043215650, 1043217052, 1043219405, 1043238421, 1043257744, 1053303792, 1053360966, 1053372201, 1053450346, 1053458018, 1053486704, 1053499673, 1063436517, 1063452167, 1063477503, 1063482198, 1063486090, 1063499572, 1063501823, 1063526580, 1063537215, 1063562635, 1063575561, 1063611499, 1063696508, 1063851285, 1073511192, 1073524823, 1073589420, 1073808945, 1083614770, 1083654826, 1083667562, 1083681423, 1083857270, 1083949143, 1093726556, 1093755134, 1093779456, 1093814717, 1093851164, 1093927576, 1104809706, 1104834209, 1104898634, 1104913789, 1104924349, 1114106689, 1114922606, 1114932084, 1114951407, 1124000427, 1124016480, 1124055900, 1124057245, 1124064639, 1124080163, 1124088380, 1124089016, 1124296298, 1124356043, 1134139884, 1134213796, 1134228794, 1134280779, 1134285059, 1134286958, 1134401136, 1144201104, 1144214578, 1144228834, 1144392499, 1144503418, 1144511700, 1154316792, 1154337129, 1154349330, 1154362937, 1154391001, 1154413110, 1154471621, 1154484749, 1154498277, 1164414769, 1164436960, 1164443958, 1164451068, 1164458006, 1164459350, 1164515003, 1164598140, 1164636932, 1174506711, 1174510549, 1174543342, 1174545271, 1174550602, 1174561708, 1174571285, 1174576912, 1174603930, 1174693949, 1174706295, 1174839047, 1184616310, 1184623951, 1184644122, 1184659849, 1184668048, 1184710691, 1184727745, 1184785354, 1184786196, 1184937799, 1194044925, 1194702076, 1194745695, 1194801662, 1194807255, 1194869727, 1194893198, 1205023512, 1205078524, 1205806163, 1205813441, 1205814266, 1205824117, 1205840451, 1205874484, 1205890027, 1205922747, 1205948577, 1205954955, 1205963402, 1215020060, 1215053665, 1215081773, 1215145552, 1215917042, 1215941349, 1215951488, 1215963715, 1215999578, 1225011612, 1225022627, 1225029275, 1225067044, 1225082886, 1225111933, 1225129349, 1225144264, 1225188766, 1235133794, 1235135138, 1235138413, 1235186636, 1235200775, 1235211095, 1245210764, 1245212471, 1245231406, 1245246925, 1245253012, 1245264415, 1245279645, 1245298371, 1245317874, 1245337864, 1245350594, 1245390020, 1245425974, 1255308797, 1255309175, 1255312625, 1255336079, 1255339677, 1255397204, 1255421541, 1255452454, 1265468409, 1265531388, 1265784680, 1275502932, 1275587123, 1275588485, 1275649048, 1275721144, 1275746554, 1275748675, 1275773046, 1285608521, 1285613778, 1285630186, 1285651638, 1285663682, 1285673012, 1285676734, 1285757310, 1285784066, 1295705291, 1295722163, 1295731479, 1295744530, 1295774487, 1295776094, 1295809358, 1295824837, 1295836245, 1306240171, 1306830021, 1306831300, 1306867742, 1306881107, 1306894118, 1306906854, 1306919162, 1316005036, 1316008766, 1316066970, 1316151525, 1316256993, 1316906456, 1316935406, 1316947807, 1316984750, 1316993520, 1326044835, 1326151507, 1326187626, 1336107184, 1336132786, 1336186600, 1336187814, 1336203603, 1336220425, 1336246487, 1336248723, 1336457571, 1346207776, 1346224821, 1346237096, 1346239084, 1346274966, 1346324316, 1356333645, 1356339055, 1356354252, 1356450274, 1356454292, 1366428773, 1366474512, 1366509903, 1366514432, 1366533390, 1376546283, 1376548552, 1376550442, 1376596726, 1376629717, 1376698936, 1376724229, 1376737809, 1376974824, 1386631869, 1386649507, 1386670461, 1386695591, 1386758134, 1396070603, 1396736260, 1396744892, 1396825147, 1396906160, 1407062094, 1407824121, 1407835473, 1407837487, 1407867666, 1407923568, 1407929698, 1417008756, 1417060120, 1417938663, 1417967647, 1427000819, 1427029479, 1427029925, 1427034271, 1427053388, 1427071059, 1427081223, 1427090562, 1427097534, 1427098268, 1427163427, 1427271485, 1437110319, 1437149952, 1437177342, 1437217601, 1437339900, 1447202205, 1447243373, 1447258157, 1447292297, 1447337936, 144 ...

# %%
len(fraud_2014)
# Out:
# 722

# %%
fraud_df14=pd.DataFrame(fraud_2014)

# %%
fraud_df14.columns=['Fraud_id_14']

# %%
fraud_df14_pkl=open("fraud_df14_pickle","wb")
pickle.dump(fraud_df14,fraud_df14_pkl)
fraud_df14_pkl.close()

# %%
fraud_df14_pkl=open("fraud_df14_pickle","rb")
fraud_df14=pickle.load(fraud_df14_pkl)
print(fraud_df14.head(5))
# Out:
#    Fraud_id_14
# 0   1003811167
# 1   1003817743
# 2   1003822834
# 3   1003859885
# 4   1003878711

# %%
fraud_df14.to_csv('fraud_df14.csv')

# %% [markdown]
# ### 2013

# %%
data2013=pd.read_table('Medicare_Provider_Util_Payment_PUF_CY2013.txt',low_memory=False)

# %%
data2013.shape
# Out:
# (9287877, 28)

# %%
data2013.columns.values
# Out:
# array(['NPI', 'NPPES_PROVIDER_LAST_ORG_NAME', 'NPPES_PROVIDER_FIRST_NAME',
#        'NPPES_PROVIDER_MI', 'NPPES_CREDENTIALS', 'NPPES_PROVIDER_GENDER',
#        'NPPES_ENTITY_CODE', 'NPPES_PROVIDER_STREET1',
#        'NPPES_PROVIDER_STREET2', 'NPPES_PROVIDER_CITY',
#        'NPPES_PROVIDER_ZIP', 'NPPES_PROVIDER_STATE',
#        'NPPES_PROVIDER_COUNTRY', 'PROVIDER_TYPE',
#        'MEDICARE_PARTICIPATION_INDICATOR', 'PLACE_OF_SERVICE',
#        'HCPCS_CODE', 'HCPCS_DESCRIPTION', 'HCPCS_DRUG_INDICATOR',
#        'LINE_SRVC_CNT', 'BENE_UNIQUE_CNT', 'BENE_DAY_SRVC_CNT',
#        'AVERAGE_MEDICARE_ALLOWED_AMT', 'STDEV_MEDICARE_ALLOWED_AMT',
#        'AVERAGE_SUBMITTED_CHRG_AMT', 'STDEV_SUBMITTED_CHRG_AMT',
#        'AVERAGE_MEDICARE_PAYMENT_AMT', 'STDEV_MEDICARE_PAYMENT_AMT'],
#       dtype=object)

# %%
checklist2013=data2013['NPI'].unique()
len(checklist2013)
# Out:
# 909606

# %%
fraud_2013=find_fraud(checklist2013,fraud_list)
print(fraud_2013)
# Out:
# [1003042441, 1003809195, 1003811167, 1003817743, 1003822834, 1003854159, 1003859885, 1003878711, 1003886979, 1003892746, 1003902800, 1003904830, 1003972670, 1003999376, 1013009729, 1013056670, 1013059740, 1013063064, 1013087741, 1013093178, 1013095975, 1013097708, 1013957182, 1013999002, 1023000122, 1023004587, 1023006129, 1023079274, 1023094190, 1023119898, 1023166410, 1023208675, 1033126651, 1033136544, 1033145487, 1033206800, 1033261953, 1033295332, 1043213887, 1043215650, 1043217052, 1043219405, 1043238421, 1043257744, 1043312168, 1043369093, 1053303792, 1053354787, 1053357376, 1053360966, 1053372201, 1053393405, 1053417345, 1053450346, 1053458018, 1053486704, 1053499673, 1063417368, 1063436517, 1063452167, 1063477503, 1063482198, 1063486090, 1063499572, 1063501823, 1063526580, 1063537215, 1063562635, 1063575561, 1063583060, 1063611499, 1063696508, 1063851285, 1073511192, 1073524823, 1073589420, 1073808945, 1083614770, 1083654826, 1083667562, 1083681423, 1083726921, 1083763874, 1083803563, 1093726556, 1093755134, 1093779456, 1093805012, 1093814717, 1093851164, 1093877144, 1093892119, 1093927576, 1093969412, 1104809706, 1104834209, 1104860253, 1104891498, 1104898634, 1104909043, 1104913789, 1104924349, 1114072444, 1114106689, 1114922606, 1114932084, 1114955325, 1114972262, 1124000427, 1124016480, 1124055900, 1124057245, 1124064639, 1124080163, 1124088380, 1124089016, 1124097068, 1124192042, 1124244850, 1124296298, 1124356043, 1134139884, 1134213796, 1134228794, 1134280779, 1134285059, 1134286958, 1134401136, 1144201104, 1144202805, 1144214578, 1144228834, 1144306176, 1144330556, 1144392499, 1154316792, 1154337129, 1154349330, 1154362937, 1154363109, 1154391001, 1154413110, 1154471621, 1154484749, 1154490134, 1154498277, 1154502623, 1164414769, 1164436960, 1164443958, 1164451068, 1164458006, 1164459350, 1164515003, 1164598140, 1164636932, 1174500474, 1174506711, 1174543342, 1174545271, 1174550602, 1174561708, 1174571285, 1174576912, 1174589618, 1174603930, 1174693949, 1174706295, 1184616310, 1184623951, 1184644122, 1184654188, 1184658346, 1184659849, 1184668048, 1184710691, 1184727745, 1184785354, 1184786196, 1184937799, 1194044925, 1194702076, 1194745695, 1194801662, 1194869727, 1205000353, 1205008125, 1205023512, 1205078524, 1205806163, 1205813441, 1205814266, 1205818358, 1205824117, 1205840451, 1205874484, 1205890027, 1205922747, 1205954955, 1205963402, 1215020060, 1215053665, 1215081773, 1215145552, 1215917042, 1215941349, 1215951488, 1215963715, 1215973011, 1215999578, 1225011612, 1225022627, 1225029275, 1225067044, 1225082886, 1225111933, 1225129349, 1225144264, 1225145196, 1225188766, 1235133794, 1235135138, 1235138413, 1235182189, 1235186636, 1235200775, 1235211095, 1235215153, 1235308172, 1245210764, 1245212471, 1245227891, 1245231406, 1245246925, 1245253012, 1245264415, 1245279645, 1245285428, 1245298371, 1245317874, 1245337864, 1245350594, 1245390020, 1245425974, 1255306767, 1255308797, 1255309175, 1255312625, 1255336079, 1255339677, 1255376216, 1255378402, 1255378592, 1255397204, 1255421541, 1255452454, 1255463576, 1265468409, 1265469472, 1265531388, 1265551451, 1265784680, 1275502932, 1275534935, 1275559338, 1275587123, 1275588485, 1275588873, 1275649048, 1275721144, 1275737504, 1275746554, 1275748675, 1285608521, 1285613778, 1285614511, 1285630186, 1285651638, 1285673012, 1285676734, 1285712950, 1285757310, 1285784066, 1295705291, 1295722163, 1295731479, 1295744530, 1295774487, 1295776094, 1295809358, 1295824837, 1295836245, 1306830021, 1306831300, 1306853221, 1306867742, 1306895578, 1306906854, 1306919162, 1316005036, 1316008766, 1316066970, 1316151525, 1316256993, 1316906456, 1316935406, 1316939945, 1316947807, 1316984750, 1316993520, 1316993553, 1326044835, 1326093709, 1326105032, 1326151507, 1326187626, 1336107184, 1336186600, 1336187814, 1336203603, 1336220425, 1336246487, 1336248723, 1336457571, 1346207776, 1346224821, 1346224987, 1346237096, 1346239084, 1346241247, 1346274966, 1346324316, 1346345071, 134 ...

# %%
len(fraud_2013)
# Out:
# 906

# %%
fraud_df13=pd.DataFrame(fraud_2013)

# %%
fraud_df13.columns=['Fraud_id_13']

# %%
fraud_df13_pkl=open("fraud_df13_pickle","wb")
pickle.dump(fraud_df13,fraud_df13_pkl)
fraud_df13_pkl.close()

# %%
fraud_df13_pkl=open("fraud_df13_pickle","rb")
fraud_df13=pickle.load(fraud_df13_pkl)
print(fraud_df13.head(5))
# Out:
#    Fraud_id_13
# 0   1003042441
# 1   1003809195
# 2   1003811167
# 3   1003817743
# 4   1003822834

# %%
fraud_df13.to_csv('fraud_df13.csv')

# %% [markdown]
# ### 2012

# %%
data2012=pd.read_table('Medicare_Provider_Util_Payment_PUF_CY2012.txt',low_memory=False)

# %%
data2012.shape
# Out:
# (9153272, 28)

# %%
checklist2012=data2012['National Provider Identifier'].unique()
len(checklist2012)
# Out:
# 880644

# %%
fraud_2012=find_fraud(checklist2012,fraud_list)
print(fraud_2012)
# Out:
# [1255378592, 1871522540, 1154337129, 1689986945, 1225148562, 1063575561, 1760541312, 1508125600, 1598713430, 1730291261, 1972687754, 1851329429, 1124057245, 1134401136, 1346224987, 1578754362, 1063436517, 1043238421, 1770553521, 1225029275, 1932260064, 1972614451, 1104860253, 1245298371, 1538359104, 1477645836, 1376596726, 1346438140, 1346274966, 1154391001, 1982601704, 1326065913, 1114932084, 1629085105, 1316008766, 1306919162, 1144214578, 1063452167, 1588694343, 1588783351, 1578549051, 1205813441, 1164414769, 1093851164, 1770667677, 1356354252, 1841230166, 1679565204, 1700907771, 1164458006, 1558478529, 1033145487, 1417931213, 1922068733, 1750451613, 1922058767, 1528284502, 1881622090, 1619952561, 1902916984, 1205000353, 1306831300, 1982637856, 1306853221, 1831145929, 1295836245, 1205023512, 1245390020, 1083803563, 1205954955, 1316984750, 1841303310, 1407923568, 1699717843, 1528052735, 1760576755, 1699748228, 1538237482, 1215917042, 1356450274, 1669403457, 1124000427, 1659324747, 1588734081, 1508904798, 1144330556, 1750472825, 1295731479, 1528088325, 1053450346, 1063562635, 1609979749, 1568546497, 1942406830, 1477571818, 1881664829, 1972607398, 1437110319, 1942265061, 1780615252, 1710089925, 1811984594, 1922005321, 1740290253, 1922103258, 1942203880, 1548278930, 1518937499, 1881678548, 1952433963, 1770656506, 1316256993, 1568428449, 1346345071, 1184710691, 1336187814, 1174545271, 1417967647, 1275588873, 1053458018, 1740380997, 1699836783, 1174743603, 1053499673, 1124016480, 1689645608, 1942249883, 1831149087, 1083632699, 1174506711, 1285614511, 1720255144, 1619169406, 1225111933, 1083726921, 1962539619, 1730160193, 1699872721, 1689649212, 1851451819, 1083681423, 1831151356, 1578697421, 1265551451, 1407803091, 1891743654, 1407813488, 1770505729, 1497778153, 1194801662, 1891748547, 1780607978, 1851392138, 1639196108, 1235135138, 1124055900, 1376550442, 1295776094, 1205922747, 1285651638, 1578605614, 1821022955, 1912932815, 1174589618, 1184623951, 1376576066, 1043369093, 1568410496, 1255309175, 1417139692, 1245212471, 1366509903, 1780666198, 1619941614, 1902090194, 1659445690, 1134280779, 1497712418, 1639395395, 1013095975, 1659510972, 1356333645, 1700981917, 1508863531, 1891732442, 1235282088, 1891793147, 1316947807, 1053334524, 1083654826, 1497779649, 1144201104, 1720209521, 1699757971, 1083612493, 1952493678, 1942202841, 1164459350, 1568476968, 1427034271, 1427029925, 1558364166, 1619930260, 1356341911, 1871528117, 1023004587, 1093726556, 1437149952, 1639175763, 1417008756, 1245425974, 1174500474, 1326002445, 1942278098, 1164659249, 1285613778, 1578605812, 1144286915, 1790785277, 1154498277, 1033136544, 1578551370, 1144202805, 1982661385, 1831142991, 1881693109, 1497732994, 1962534909, 1427098268, 1669412243, 1871596098, 1285673012, 1902874456, 1972839447, 1174543342, 1003886979, 1245210764, 1083614770, 1891772786, 1336203603, 1992717250, 1376552117, 1710065958, 1679542914, 1891752564, 1639183676, 1427090562, 1528034378, 1467447557, 1881736346, 1154471621, 1245246925, 1720060460, 1376546283, 1275587123, 1295824837, 1053486704, 1114106689, 1760558548, 1043215650, 1154349330, 1841393097, 1053354787, 1174510549, 1417989476, 1962443739, 1245227891, 1285712950, 1578524237, 1831202126, 1255421541, 1023119898, 1821097130, 1821037508, 1477546463, 1235182189, 1801846712, 1295705291, 1528111341, 1417065186, 1023166410, 1871663740, 1538321047, 1023079274, 1134139884, 1588775118, 1730264854, 1275649048, 1013093178, 1245375567, 1972694677, 1548376965, 1669422523, 1447202205, 1154362937, 1477594935, 1437177342, 1225022627, 1053372201, 1215974886, 1255463576, 1962448464, 1235186636, 1578669859, 1881660959, 1902845480, 1407062094, 1669414397, 1689641458, 1649207853, 1679606560, 1619168036, 1578679221, 1679639397, 1578616009, 1154434439, 1013998640, 1770534745, 1891780425, 1841206307, 1194745695, 1720023005, 1194869727, 1205840451, 1740340264, 1821058694, 1114972262, 1376548552, 1912069394, 1235133794, 1720159916, 1932147410, 1912939760, 109 ...

# %%
len(fraud_2012)
# Out:
# 1149

# %%
fraud_df12.columns=['Fraud_id_12']

# %%
fraud_df12_pkl=open("fraud_df12_pickle","wb")
pickle.dump(fraud_df12,fraud_df12_pkl)
fraud_df12_pkl.close()

# %%
fraud_df12_pkl=open("fraud_df12_pickle","rb")
fraud_df12=pickle.load(fraud_df12_pkl)
print(fraud_df12.head(5))
# Out:
#    Fraud_id_12
# 0   1255378592
# 1   1871522540
# 2   1154337129
# 3   1689986945
# 4   1225148562

# %%
fraud_df12.to_csv('fraud_df12.csv')

# %% [markdown]
# ### Step 3:  Fraud Data in between 2012-2016 Data Sets

# %% [markdown]
# #### Total number of pysicians found in 2_2019 LEIE between 2012-2016

# %%
combined_fraud_id=pd.concat([fraud_df12, fraud_df13], axis=0, ignore_index=True)
combined_fraud_id=pd.concat([combined_fraud_id, fraud_df14], axis=0, ignore_index=True)
combined_fraud_id=pd.concat([combined_fraud_id, fraud_df15], axis=0, ignore_index=True)
combined_fraud_id=pd.concat([combined_fraud_id, fraud_df16], axis=0, ignore_index=True)

# %%
combined_fraud_id.columns=['npi']

# %%
fraud_id_unique=combined_fraud_id['npi'].unique()

# %%
len(fraud_id_unique)
# Out:
# 1235

# %% [markdown]
# #### Total number of pysicians between 2012-2016

# %%
checklist2012=pd.DataFrame(checklist2012)
checklist2013=pd.DataFrame(checklist2013)
checklist2014=pd.DataFrame(checklist2014)
checklist2015=pd.DataFrame(checklist2015)
checklist2016=pd.DataFrame(checklist2016)

# %%
total_id=pd.concat([checklist2012, checklist2013], axis=0, ignore_index=True)
total_id=pd.concat([total_id,checklist2014], axis=0, ignore_index=True)
total_id=pd.concat([total_id, checklist2015], axis=0, ignore_index=True)
total_id=pd.concat([total_id, checklist2016], axis=0, ignore_index=True)

# %%
total_id.columns=['npi']

# %%
total_unique=total_id['npi'].unique()

# %%
len(total_unique)
# Out:
# 1221295

# %%
#total_id.to_csv('total_id_npi.csv')

# %% [markdown]
# #### Crime Rate between 2012-2016

# %%
len(fraud_id_unique)/len(total_unique)
# Out:
# 0.0010112216950040735

# %% [markdown]
# #### Number of fraud npi  continous between 2012-2016

# %%
fraud_id_yrs=combined_fraud_id.groupby(['npi']).size()

# %%
a=fraud_id_yrs.index

# %%
b=fraud_id_yrs.tolist()

# %%
fraud_id_yrs=pd.DataFrame({'npi':a,'num_yrs':b })

# %%
fraud_id_yrs.head(5)
# Out:
#           npi  num_yrs
# 0  1003042441        2
# 1  1003809195        2
# 2  1003811167        5
# 3  1003817743        5
# 4  1003822834        5

# %%
len(fraud_id_yrs[fraud_id_yrs.num_yrs==5])
# Out:
# 247

# %%
fraud_id_yrs.to_csv('fraud_id_yrs.csv')

# %% [markdown]
# ## PART II: MAP Fraud Data

# %% [markdown]
# ### Subset tables by year

# %% [markdown]
# ### 2012 subset

# %%
sub_2012=data2012[['National Provider Identifier','Provider Type', 'Gender','HCPCS Code','Number of Services', 'Number of Medicare Beneficiaries','Number of Medicare Beneficiary/Day Services','Average Submitted Charge Amount','Average Medicare Payment Amount']]

# %%
sub_2012.columns=['NPI','Provider_Type', 'Gender','HCPCS_c','Num_Services', 'Num_Beneficiaries','Num_Service_Daily','Ave_Charge','Ave_Payment']

# %%
print(sub_2012.head(10))
# Out:
#           NPI         Provider_Type Gender HCPCS_c  Num_Services  \
# 0  1740238153  Diagnostic Radiology      M   72100          34.0
# 1  1871676908     Internal Medicine      M   93000          67.0
# 2  1396700191             Pathology      F   88311          48.0
# 3  1548218720   Physician Assistant      F   99213         113.0
# 4  1356363477      Vascular Surgery      M   75625          42.0
# 5  1053401950  Diagnostic Radiology      M   72291          26.0
# 6  1962522201   Clinical Laboratory    NaN   80069          80.0
# 7  1881665719  Diagnostic Radiology      M   74160          17.0
# 8  1770781452       Family Practice      M   93880          82.0
# 9  1447205752  Diagnostic Radiology      M   72170          34.0
#
#    Num_Beneficiaries  Num_Service_Daily  Ave_Charge  Ave_Payment
# 0                 33                 33   22.928235     9.346765
# 1                 64                 67   57.137910    13.365075
# 2                 45                 45   75.000000     9.950000
# 3                 93                113   82.203540    33.869558
# 4                 39                 42  576.000000    42.490000
# 5                 18                 19   78.500000    52.755000
# 6                 65                 80   47.034500    11.893500
# 7                 16                 17  187.000000    42.934706
# 8                 80                 82  552.256098   110.222683
# 9                 30                 32   23.882353     6.675000

# %% [markdown]
# ### 2013 subset

# %%
sub_2013=data2013[['NPI','PROVIDER_TYPE','NPPES_PROVIDER_GENDER','HCPCS_CODE', 'LINE_SRVC_CNT','BENE_UNIQUE_CNT', 'BENE_DAY_SRVC_CNT', 'AVERAGE_SUBMITTED_CHRG_AMT', 'AVERAGE_MEDICARE_PAYMENT_AMT']]

# %%
sub_2013.columns=['NPI','Provider_Type', 'Gender','HCPCS_c','Num_Services', 'Num_Beneficiaries','Num_Service_Daily','Ave_Charge','Ave_Payment']

# %%
print(sub_2013.head(10))
# Out:
#           NPI      Provider_Type Gender HCPCS_c  Num_Services  \
# 0           1                NaN    NaN     NaN           NaN
# 1  1003000126  Internal Medicine      M   99222         142.0
# 2  1003000126  Internal Medicine      M   99223          96.0
# 3  1003000126  Internal Medicine      M   99231          61.0
# 4  1003000126  Internal Medicine      M   99232         777.0
# 5  1003000126  Internal Medicine      M   99233         170.0
# 6  1003000126  Internal Medicine      M   99238         219.0
# 7  1003000126  Internal Medicine      M   99239         142.0
# 8  1003000134          Pathology      M   88304         209.0
# 9  1003000134          Pathology      M   88305        5786.0
#
#    Num_Beneficiaries  Num_Service_Daily  Ave_Charge  Ave_Payment
# 0                NaN                NaN         NaN          NaN
# 1              138.0              142.0  368.626761   104.299718
# 2               95.0               96.0  524.604167   155.901146
# 3               47.0               61.0   97.000000    30.065246
# 4              381.0              777.0  187.594595    55.091351
# 5              106.0              170.0  271.976471    80.641235
# 6              208.0              219.0  201.004566    55.650457
# 7              137.0              142.0  245.830986    82.632113
# 8              201.0              204.0  115.000000     9.327464
# 9             3771.0             4632.0  170.000000    29.279589

# %% [markdown]
# ### 2014 subset

# %%
data2014.columns.values
# Out:
# array(['npi', 'nppes_provider_last_org_name', 'nppes_provider_first_name',
#        'nppes_provider_mi', 'nppes_credentials', 'nppes_provider_gender',
#        'nppes_entity_code', 'nppes_provider_street1',
#        'nppes_provider_street2', 'nppes_provider_city',
#        'nppes_provider_zip', 'nppes_provider_state',
#        'nppes_provider_country', 'provider_type',
#        'medicare_participation_indicator', 'number_of_hcpcs',
#        'total_services', 'total_unique_benes', 'total_submitted_chrg_amt',
#        'total_medicare_allowed_amt', 'total_medicare_payment_amt',
#        'total_medicare_stnd_amt', 'drug_suppress_indicator',
#        'number_of_drug_hcpcs', 'total_drug_services',
#        'total_drug_unique_benes', 'total_drug_submitted_chrg_amt',
#        'total_drug_medicare_allowed_amt',
#        'total_drug_medicare_payment_amt', 'total_drug_medicare_stnd_amt',
#        'med_suppress_indicator', 'number_of_med_hcpcs',
#        'total_med_services', 'total_med_unique_benes',
#        'total_med_submitted_chrg_amt', 'total_med_medicare_allowed_amt',
#        'total_med_medicare_payment_amt', 'total_med_medicare_stnd_amt',
#        'beneficiary_average_age', 'beneficiary_age_less_65_count',
#        'beneficiary_age_65_74_count', 'beneficiary_age_75_84_count',
#        'beneficiary_age_greater_84_count', 'beneficiary_female_count',
#        'beneficiary_male_count', 'beneficiary_race_white_count',
#        'beneficiary_race_black_count', 'beneficiary_race_api_count',
#        'beneficiary_race_hispanic_count', 'beneficiary_race_natind_count',
#        'beneficiary_race_other_count', 'beneficiary_nondual_count',
#        'beneficiary_dual_count', 'beneficiary_cc_afib_percent',
#        'beneficiary_cc_alzrdsd_percent', 'beneficiary_cc_asthma_percent',
#        'beneficiary_cc_cancer_percent', 'beneficiary_cc_chf_percent',
#        'beneficiary_cc_ckd_percent', 'beneficiary_cc_copd_percent',
#        'beneficiary_cc_depr_percent', 'beneficiary_cc_diab_percent',
#        'beneficiary_cc_hyperl_percent', 'beneficiary_cc_hypert_percent',
#        'beneficiary_cc_ihd_percent', 'beneficiary_cc_ost_percent',
#        'beneficiary_cc_raoa_percent', 'beneficiary_cc_schiot_percent',
#        'beneficiary_cc_strk_percent', 'Beneficiary_Average_Risk_Score'],
#       dtype=object)

# %%
sub_2014=data2014[['npi','provider_type','nppes_provider_gender','number_of_hcpcs','total_services','total_med_unique_benes', 'total_med_services', 'total_drug_submitted_chrg_amt', 'total_med_medicare_payment_amt']]

# %%
sub_2014.columns=['NPI','Provider_Type', 'Gender','HCPCS_c','Num_Services', 'Num_Beneficiaries','Num_Service_Daily','Ave_Charge','Ave_Payment']

# %%
print(sub_2014.head(10))
# Out:
#           NPI          Provider_Type Gender  HCPCS_c  Num_Services  \
# 0  1003000126      Internal Medicine      M       16        2749.0
# 1  1003000134              Pathology      M       13        8643.0
# 2  1003000142         Anesthesiology      M       40         654.0
# 3  1003000407        Family Practice      M       39        1012.0
# 4  1003000423  Obstetrics/Gynecology      F       29         293.0
# 5  1003000480        General Surgery      M       62         238.0
# 6  1003000522        Family Practice      M       34        1619.0
# 7  1003000530      Internal Medicine      F       32         848.0
# 8  1003000639        Cardiac Surgery      M       29          48.0
# 9  1003000704         Anesthesiology      M       43         140.0
#
#    Num_Beneficiaries  Num_Service_Daily  Ave_Charge  Ave_Payment
# 0              913.0             2749.0         0.0    194073.09
# 1             4276.0             8643.0         0.0    245364.34
# 2              165.0              654.0         0.0     51820.04
# 3              392.0             1012.0         0.0     85665.04
# 4                NaN                NaN         NaN          NaN
# 5              153.0              238.0         0.0     47097.18
# 6                NaN                NaN         NaN          NaN
# 7              302.0              707.0      9872.0     36669.37
# 8               30.0               48.0         0.0     19542.01
# 9              101.0              140.0         0.0     17572.93

# %% [markdown]
# ### 2015 subset

# %%
data2015.columns.values
# Out:
# array(['npi', 'nppes_provider_last_org_name', 'nppes_provider_first_name',
#        'nppes_provider_mi', 'nppes_credentials', 'nppes_provider_gender',
#        'nppes_entity_code', 'nppes_provider_street1',
#        'nppes_provider_street2', 'nppes_provider_city',
#        'nppes_provider_zip', 'nppes_provider_state',
#        'nppes_provider_country', 'provider_type',
#        'medicare_participation_indicator', 'place_of_service',
#        'hcpcs_code', 'hcpcs_description', 'hcpcs_drug_indicator',
#        'line_srvc_cnt', 'bene_unique_cnt', 'bene_day_srvc_cnt',
#        'average_Medicare_allowed_amt', 'average_submitted_chrg_amt',
#        'average_Medicare_payment_amt', 'average_Medicare_standard_amt'],
#       dtype=object)

# %%
sub_2015=data2015[['npi', 'provider_type', 'nppes_provider_gender','hcpcs_code','line_srvc_cnt', 'bene_unique_cnt','bene_day_srvc_cnt', 'average_Medicare_allowed_amt', 'average_Medicare_payment_amt']]

# %%
sub_2015.columns=['NPI','Provider_Type', 'Gender','HCPCS_c','Num_Services', 'Num_Beneficiaries','Num_Service_Daily','Ave_Charge','Ave_Payment']

# %%
print(sub_2015.head(10))
# Out:
#           NPI      Provider_Type Gender HCPCS_c  Num_Services  \
# 0           1                NaN    NaN     NaN           NaN
# 1  1003000126  Internal Medicine      M   99217          23.0
# 2  1003000126  Internal Medicine      M   99219          18.0
# 3  1003000126  Internal Medicine      M   99221          59.0
# 4  1003000126  Internal Medicine      M   99222         132.0
# 5  1003000126  Internal Medicine      M   99223         220.0
# 6  1003000126  Internal Medicine      M   99231          38.0
# 7  1003000126  Internal Medicine      M   99232        1117.0
# 8  1003000126  Internal Medicine      M   99233         580.0
# 9  1003000126  Internal Medicine      M   99238         175.0
#
#    Num_Beneficiaries  Num_Service_Daily  Ave_Charge  Ave_Payment
# 0                NaN                NaN         NaN          NaN
# 1               23.0               23.0   72.680000    54.502609
# 2               18.0               18.0  135.850000   100.958889
# 3               58.0               59.0  101.365085    79.469661
# 4              130.0              132.0  139.010455   107.933409
# 5              215.0              220.0  205.185955   157.908955
# 6               18.0               38.0   39.554737    31.015789
# 7              481.0             1117.0   73.251164    56.313859
# 8              286.0              580.0  105.481845    80.929379
# 9              172.0              175.0   73.987143    57.079486

# %% [markdown]
# ### 2016 subset

# %%
data2016.columns.values
# Out:
# array(['NPI', 'NPPES_PROVIDER_LAST_ORG_NAME', 'NPPES_PROVIDER_FIRST_NAME',
#        'NPPES_PROVIDER_MI', 'NPPES_CREDENTIALS', 'NPPES_PROVIDER_GENDER',
#        'NPPES_ENTITY_CODE', 'NPPES_PROVIDER_STREET1',
#        'NPPES_PROVIDER_STREET2', 'NPPES_PROVIDER_CITY',
#        'NPPES_PROVIDER_ZIP', 'NPPES_PROVIDER_STATE',
#        'NPPES_PROVIDER_COUNTRY', 'PROVIDER_TYPE',
#        'MEDICARE_PARTICIPATION_INDICATOR', 'PLACE_OF_SERVICE',
#        'HCPCS_CODE', 'HCPCS_DESCRIPTION', 'HCPCS_DRUG_INDICATOR',
#        'LINE_SRVC_CNT', 'BENE_UNIQUE_CNT', 'BENE_DAY_SRVC_CNT',
#        'AVERAGE_MEDICARE_ALLOWED_AMT', 'AVERAGE_SUBMITTED_CHRG_AMT',
#        'AVERAGE_MEDICARE_PAYMENT_AMT', 'AVERAGE_MEDICARE_STANDARD_AMT'],
#       dtype=object)

# %%
sub_2016=data2016[['NPI', 'PROVIDER_TYPE','NPPES_PROVIDER_GENDER','HCPCS_CODE', 'LINE_SRVC_CNT', 'BENE_UNIQUE_CNT', 'BENE_DAY_SRVC_CNT','AVERAGE_MEDICARE_ALLOWED_AMT','AVERAGE_MEDICARE_PAYMENT_AMT']]

# %%
sub_2016.columns=['NPI','Provider_Type', 'Gender','HCPCS_c','Num_Services', 'Num_Beneficiaries','Num_Service_Daily','Ave_Charge','Ave_Payment']

# %%
print(sub_2016.head(10))
# Out:
#           NPI      Provider_Type Gender HCPCS_c  Num_Services  \
# 0           1                NaN    NaN     NaN           NaN
# 1  1003000126  Internal Medicine      M   99217          57.0
# 2  1003000126  Internal Medicine      M   99219          38.0
# 3  1003000126  Internal Medicine      M   99220          23.0
# 4  1003000126  Internal Medicine      M   99221          20.0
# 5  1003000126  Internal Medicine      M   99222          96.0
# 6  1003000126  Internal Medicine      M   99223         148.0
# 7  1003000126  Internal Medicine      M   99225          11.0
# 8  1003000126  Internal Medicine      M   99232         596.0
# 9  1003000126  Internal Medicine      M   99233         117.0
#
#    Num_Beneficiaries  Num_Service_Daily  Ave_Charge  Ave_Payment
# 0                NaN                NaN         NaN          NaN
# 1               55.0               57.0   72.743158    54.474386
# 2               38.0               38.0  135.010000   105.850000
# 3               23.0               23.0  189.239565   146.116522
# 4               20.0               20.0  100.750000    78.990000
# 5               87.0               96.0  136.250000   105.477604
# 6              141.0              148.0  203.793919   159.083446
# 7               11.0               11.0   72.480000    56.820000
# 8              270.0              596.0   71.864362    56.210990
# 9               85.0              117.0  103.540000    80.909316

# %% [markdown]
# ### Reverse Method - To find new added Fraud NPI among 2012-2016

# %% [markdown]
# ### 2015-2016

# %%
fraud_npi_1516=[i for i, j in zip(fraud_2015,fraud_2016 ) if i != j]
len(fraud_npi_1516)
# Out:
# 281

# %%
#check fraud_npi_1516 list 
fraud_npi_1516
# Out:
# [1003042441,
#  1003811167,
#  1003817743,
#  1003822834,
#  1003859885,
#  1003885344,
#  1003892746,
#  1003904830,
#  1003972670,
#  1013009729,
#  1013087741,
#  1013095975,
#  1013097708,
#  1013999002,
#  1023004587,
#  1023006129,
#  1023079274,
#  1023119898,
#  1023166410,
#  1033126651,
#  1033145487,
#  1043215650,
#  1043219405,
#  1043238421,
#  1043257744,
#  1053360966,
#  1053372201,
#  1053450346,
#  1053486704,
#  1063436517,
#  1063452167,
#  1063477503,
#  1063486090,
#  1063501823,
#  1063526580,
#  1063537215,
#  1063575561,
#  1063611499,
#  1063696508,
#  1063851285,
#  1073511192,
#  1073524823,
#  1083614770,
#  1083654826,
#  1083667562,
#  1083681423,
#  1093726556,
#  1093755134,
#  1093814717,
#  1093851164,
#  1104809706,
#  1104898634,
#  1104913789,
#  1104924349,
#  1114106689,
#  1114922606,
#  1114951407,
#  1124000427,
#  1124016480,
#  1124057245,
#  1124088380,
#  1124089016,
#  1124192042,
#  1124296298,
#  1124356043,
#  1124423983,
#  1134213796,
#  1134228794,
#  1134280779,
#  1134285059,
#  1134286958,
#  1144214578,
#  1144228834,
#  1144503418,
#  1144511700,
#  1154337129,
#  1154349330,
#  1154413110,
#  1154471621,
#  1164414769,
#  1164436960,
#  1164458006,
#  1164459350,
#  1164515003,
#  1164598140,
#  1174510549,
#  1174545271,
#  1174561708,
#  1174571285,
#  1174576912,
#  1184644122,
#  1184659849,
#  1184710691,
#  1184727745,
#  1184785354,
#  1184937799,
#  1194702076,
#  1194745695,
#  1194801662,
#  1194893198,
#  1205023512,
#  1205806163,
#  1205824117,
#  1205840451,
#  1205874484,
#  1205954955,
#  1205963402,
#  1215053665,
#  1215081773,
#  1215099585,
#  1215328323,
#  1215917042,
#  1215941349,
#  1215951488,
#  1215963715,
#  1215999578,
#  1225022627,
#  1225029275,
#  1225067044,
#  1225111933,
#  1225144264,
#  1235135138,
#  1235138413,
#  1235186636,
#  1235200775,
#  1235211095,
#  1245210764,
#  1245231406,
#  1245246925,
#  1245264415,
#  1245279645,
#  1245298371,
#  1245337864,
#  1245425974,
#  1255309175,
#  1255312625,
#  1255339677,
#  1255397204,
#  1255452454,
#  1265531388,
#  1265784680,
#  1275502932,
#  1275587123,
#  1275649048,
#  1275721144,
#  1275748675,
#  1275773046,
#  1285613778,
#  1285630186,
#  1285651638,
#  1285663682,
#  1285673012,
#  1285676734,
#  1285757310,
#  1285784066,
#  1295705291,
#  1295722163,
#  1295731479,
#  1295836245,
#  1306240171,
#  1306249826,
#  1306867742,
#  1306894118,
#  1306895578,
#  1306906854,
#  1316008766,
#  1316067051,
#  1316906456,
#  1316935406,
#  1316947807,
#  1316984750,
#  1316993520,
#  1326151507,
#  1326187626,
#  1336107184,
#  1336132786,
#  1336186600,
#  1336187814,
#  1336248723,
#  1346207776,
#  1346224821,
#  1346237096,
#  1346239084,
#  1356333645,
#  1356354252,
#  1356450274,
#  1366428773,
#  1366474512,
#  1366509903,
#  1366514432,
#  1366533390,
#  1376548552,
#  1376550442,
#  1376596726,
#  1376698936,
#  1376737809,
#  1386631869,
#  1386649507,
#  1386670461,
#  1386695591,
#  1396070603,
#  1396744892,
#  1407062094,
#  1407867666,
#  1407929698,
#  1417008756,
#  1417060120,
#  1417938663,
#  1417967647,
#  1427000819,
#  1427034271,
#  1427090562,
#  1427163427,
#  1437110319,
#  1437217601,
#  1437339900,
#  1447243373,
#  1447280243,
#  1447292297,
#  1447337936,
#  1457356768,
#  1457485906,
#  1457696908,
#  1467400028,
#  1467435487,
#  1467447557,
#  1467474882,
#  1467526855,
#  1477507739,
#  1477524270,
#  1477571818,
#  1477596690,
#  1487605515,
#  1487629796,
#  1497712418,
#  1497722391,
#  1497732994,
#  1497743090,
#  1497745905,
#  1497749089,
#  1497778153,
#  1497797526,
#  1497864151,
#  1497878656,
#  1508827395,
#  1508863531,
#  1518387760,
#  1518908193,
#  1518927615,
#  1528082740,
#  1528087970,
#  1528088325,
#  1528093184,
#  1528152840,
#  1528171774,
#  1528390259,
#  1538200308,
#  1538237482,
#  1538265947,
#  1538321047,
#  1538359104,
#  1538395876,
#  1548250129,
#  1548376965,
#  1548401292,
#  1548427164,
#  1558342378,
#  1558347468,
#  1558366815,
#  1558379172,
#  1558405647,
#  1558448951,
#  1558478529,
#  1558479147,
#  1568400596,
#  1578524237,
#  1578679221,
#  1578697421,
#  1578754362,
#  1588694343,
#  1588775118]

# %%
#if NIP is not in fraud_2016 list, it means NPI provider has been detected by OIG in calendar year 2015
if '1003042441' not in fraud_2016:
     print("not extist")
# Out:
# not extist

# %% [markdown]
# ### 2014-2015

# %%
temp=[i for i, j in zip(fraud_2014,fraud_2015 ) if i != j]
fraud_npi_1415=[i for i, j in zip(temp,fraud_2016 ) if i != j]
len(fraud_npi_1415)
# Out:
# 275

# %% [markdown]
# ### 2013-2014

# %%
temp=[i for i, j in zip(fraud_2013,fraud_2014) if i != j]
temp=[i for i, j in zip(temp,fraud_2015 ) if i != j]
fraud_npi_1314=[i for i, j in zip(temp,fraud_2016 ) if i != j]
len(fraud_npi_1314)
# Out:
# 281

# %% [markdown]
# ### 2012-2013

# %%
temp=[i for i, j in zip(fraud_2012,fraud_2013) if i != j]
temp=[i for i, j in zip(temp,fraud_2014) if i != j]
temp=[i for i, j in zip(temp,fraud_2015 ) if i != j]i
fraud_npi_1213=[i for i, j in zip(temp,fraud_2016 ) if  != j]
len(fraud_npi_1213)
# Out:
# 281

# %% [markdown]
# ## References:

# %% [markdown]
# [Medicare Fee-For-Service Provider Utilization & Payment Data Physician and Other Supplier Public Use File: A Methodological Overview] last updated: May 3, 2018, The Centers of Medicare and Medicare Services, Office of Enterprise Data and Analytics https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/Medicare-Provider-Charge-Data/Physician-and-Other-Supplier.html

# %% [markdown]
# [Medicare Provider Utilization and Payment Data Physician and Other Supplier PUF: Frequently Asked Questions] last updated: May 4, 2018, The Centers of Medicare and Medicare Services, Office of Enterprise Data and Analytics https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/Medicare-Provider-Charge-Data/Downloads/Physician_FAQ.pdf

# %% [markdown]
# [List of Excluded Individuals/Entities (LEIE)] 02-2019 Updated LEIE Database, https://oig.hhs.gov/exclusions/exclusions_list.asp;

# %% [markdown]
# [The Detection of Medicare Fraud Using Machine Learning Methods with Excluded Provider Labels] by Richard A. Bauder, Taghi M. Khoshgoftaar, College of Engineering & Computer Science, Florida Atlantic University (2018)
